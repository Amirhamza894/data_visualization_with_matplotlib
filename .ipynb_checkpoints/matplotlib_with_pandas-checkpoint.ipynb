# %% [markdown]
# ## Ploting From Pandas DataFrames

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
car_sales = pd.read_csv('car-sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]', '')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
type(car_sales['Price'][0])
# Out:
# str

# %%
car_sales.Price = car_sales['Price'].str[:-2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Sales Date'] = pd.date_range('4/11/2020', periods=len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2020-04-11
# 1   Honda    Red          87899      4   5000 2020-04-12
# 2  Toyota   Blue          32549      3   7000 2020-04-13
# 3     BMW  Black          11179      5  22000 2020-04-14
# 4  Nissan  White         213095      4   3500 2020-04-15
# 5  Toyota  Green          99213      4   4500 2020-04-16
# 6   Honda   Blue          45698      4   7500 2020-04-17
# 7   Honda   Blue          54738      4   7000 2020-04-18
# 8  Toyota  White          60000      4   6250 2020-04-19
# 9  Nissan  White          31600      4   9700 2020-04-20

# %%
car_sales['Total Sales'] = car_sales['Price'].astype(int).cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-04-11         4000
# 1   Honda    Red          87899      4   5000 2020-04-12         9000
# 2  Toyota   Blue          32549      3   7000 2020-04-13        16000
# 3     BMW  Black          11179      5  22000 2020-04-14        38000
# 4  Nissan  White         213095      4   3500 2020-04-15        41500
# 5  Toyota  Green          99213      4   4500 2020-04-16        46000
# 6   Honda   Blue          45698      4   7500 2020-04-17        53500
# 7   Honda   Blue          54738      4   7000 2020-04-18        60500
# 8  Toyota  White          60000      4   6250 2020-04-19        66750
# 9  Nissan  White          31600      4   9700 2020-04-20        76450

# %%
car_sales.plot(x='Sales Date', y='Total Sales');

# %%
car_sales['Price'] = car_sales['Price'].astype(int)

# %%
car_sales.plot(x='Odometer (KM)', y='Price', kind='scatter');

# %%
x = np.random.rand(10,4)

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.430090  0.871115  0.944511  0.337085
# 1  0.333607  0.137539  0.346298  0.821838
# 2  0.687247  0.337033  0.792955  0.034505
# 3  0.896347  0.663285  0.253570  0.148945
# 4  0.814657  0.141682  0.402985  0.460992
# 5  0.662393  0.353558  0.983986  0.572417
# 6  0.556261  0.472973  0.416457  0.190015
# 7  0.105481  0.253348  0.777818  0.936709
# 8  0.325890  0.564164  0.321971  0.689339
# 9  0.094078  0.541758  0.370724  0.942721

# %%
df.plot.bar();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-04-11         4000
# 1   Honda    Red          87899      4   5000 2020-04-12         9000
# 2  Toyota   Blue          32549      3   7000 2020-04-13        16000
# 3     BMW  Black          11179      5  22000 2020-04-14        38000
# 4  Nissan  White         213095      4   3500 2020-04-15        41500
# 5  Toyota  Green          99213      4   4500 2020-04-16        46000
# 6   Honda   Blue          45698      4   7500 2020-04-17        53500
# 7   Honda   Blue          54738      4   7000 2020-04-18        60500
# 8  Toyota  White          60000      4   6250 2020-04-19        66750
# 9  Nissan  White          31600      4   9700 2020-04-20        76450

# %%
car_sales.plot(x='Make', y='Price', kind='bar');

# %%
car_sales.plot(x='Make', y='Doors', kind='bar')
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
des = pd.read_csv('13.1 heart-disease.csv')

# %%
des.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
des['age'].plot.hist(bins=40);

# %% [markdown]
# ## Extract the data of patient with age 50

# %%
over_50 = des[des['age']>50]

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
## Pyplot Method
over_50.plot(x='age',
            y='chol',
            kind='scatter',
            c='target');

# %%
## OO Method
fig, ax = plt.subplots(figsize=(10,6));

over_50.plot(x='age',
            y='chol',
            kind='scatter',
            c='target',
            ax=ax);

# ax.set_xlim(50,100)

# %%
## OO Method with pyplot help
fig, ax = plt.subplots(figsize=(10,6));

scatter = ax.scatter(x=over_50['age'],
                    y=over_50['chol'],
                    c=over_50['target'])

ax.set(xlabel='Age', ylabel='cholestrol', title='Heart Disease and cholestrol level');


ax.legend(*scatter.legend_elements(),title='Target');

ax.axhline(over_50['chol'].mean(),
          linestyle='--');

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
## OO Method and visualizing previous data from scratch
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10,10))


scatter = ax0.scatter(x= over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

ax0.set(
       ylabel='Cholistrol',
       title='Heart disease and cholestrol level');

ax0.legend(*scatter.legend_elements(), title='Target')

ax0.axhline(over_50['chol'].mean(),
           linestyle='--');

scatter = ax1.scatter(x=over_50['age'],
                     y=over_50['thalach'],
                     c=over_50['target']);

ax1.set(xlabel='Age',
       ylabel='Max Heart Rate',
       title= 'Heart disease and Max Heart rate');

ax1.legend(*scatter.legend_elements(), title='Target')

ax1.axhline(over_50['thalach'].mean(), linestyle='--')

fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %% [markdown]
# ## Customizing Matplotlib Plots style

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn');

car_sales.Price.plot();

# %%
## OO Method with pyplot help

plt.style.use('seaborn-whitegrid')

fig, ax = plt.subplots(figsize=(10,6));

scatter = ax.scatter(x=over_50['age'],
                    y=over_50['chol'],
                    c=over_50['target'],
                    cmap='winter')

ax.set(xlabel='Age', ylabel='cholestrol', title='Heart Disease and cholestrol level');


ax.legend(*scatter.legend_elements(),title='Target');

ax.axhline(over_50['chol'].mean(),
          linestyle='--');

# %%
## OO Method and visualizing previous data from scratch

plt.style.use('seaborn-whitegrid')

fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10,10))


scatter = ax0.scatter(x= over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'],
                     cmap='winter');

ax0.set(
       ylabel='Cholistrol',
       title='Heart disease and cholestrol level');

ax0.legend(*scatter.legend_elements(), title='Target')

ax0.axhline(over_50['chol'].mean(),
           linestyle='--');

ax0.set_xlim([50,80])
# ax0.set_ylim([60,500])

scatter = ax1.scatter(x=over_50['age'],
                     y=over_50['thalach'],
                     c=over_50['target'],
                     cmap='winter');

ax1.set(xlabel='Age',
       ylabel='Max Heart Rate',
       title= 'Heart disease and Max Heart rate');

ax1.set_xlim([50,80])
ax1.set_ylim([60,200])

ax1.legend(*scatter.legend_elements(), title='Target')

ax1.axhline(over_50['thalach'].mean(), linestyle='--')

fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');
